# %% [raw]
# ---
# title: London visitors
# description: International London visitors dashboard
# show-code: False
# params:
#     year:
#         input: select
#         label: Please select a year
#         value: ALL
#         choices: ['ALL', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020P']
#     purpose:
#         input: select
#         label: Please select a purpose
#         value: ALL
#         choices: ['ALL', 'Business', 'Holiday', 'Miscellaneous', 'Study', 'VFR']
#     num:
#         input: numeric
#         value: 5
#         label: Please select a num filtering
#         min: 0
#         max: 100000
#         step: 1
# ---

# %%
import pandas as pd
import numpy as np
from ipywidgets import widgets

# %%
df_london = pd.read_csv("data/international-visitors-london-raw.csv")

# %%
ALL = 'ALL'

# %%
year = ALL
purpose = ALL
num = 5

# %%
def colour_ge_value(value, comparison):
    if value >= comparison:
        return 'color: red'
    else:
        return 'color: black'

# %%
def common_filtering(year, purpose, num):
    
    
    if (year == ALL) & (purpose == ALL):
        common_filter = df_london
    elif (year == ALL):
        common_filter = df_london[df_london.purpose == purpose]
    elif (purpose == ALL):
        common_filter = df_london[df_london.year == year]
    else:
        common_filter = df_london[(df_london.year == year) & 
                                  (df_london.purpose == purpose)]
    
    print("Data set size", common_filter.shape)
    return common_filter.head(20).style.applymap(
        lambda x: colour_ge_value(x, num),
        subset=['visits','spend', 'nights'])

# %%
common_filtering(year, purpose, num)
# Out:
# Data set size (61462, 11)
# <style type="text/css">
# #T_8b9ab_row0_col7, #T_8b9ab_row0_col8, #T_8b9ab_row1_col8, #T_8b9ab_row2_col7, #T_8b9ab_row2_col8, #T_8b9ab_row2_col9, #T_8b9ab_row3_col7, #T_8b9ab_row3_col8, #T_8b9ab_row3_col9, #T_8b9ab_row4_col7, #T_8b9ab_row4_col8, #T_8b9ab_row4_col9, #T_8b9ab_row5_col7, #T_8b9ab_row5_col8, #T_8b9ab_row5_col9, #T_8b9ab_row6_col8, #T_8b9ab_row7_col8, #T_8b9ab_row8_col8, #T_8b9ab_row9_col7, #T_8b9ab_row9_col8, #T_8b9ab_row9_col9, #T_8b9ab_row10_col7, #T_8b9ab_row10_col8, #T_8b9ab_row10_col9, #T_8b9ab_row11_col7, #T_8b9ab_row11_col8, #T_8b9ab_row11_col9, #T_8b9ab_row12_col7, #T_8b9ab_row12_col8, #T_8b9ab_row13_col7, #T_8b9ab_row13_col8, #T_8b9ab_row13_col9, #T_8b9ab_row14_col7, #T_8b9ab_row14_col8, #T_8b9ab_row14_col9, #T_8b9ab_row15_col7, #T_8b9ab_row15_col8, #T_8b9ab_row15_col9, #T_8b9ab_row16_col7, #T_8b9ab_row16_col8, #T_8b9ab_row16_col9, #T_8b9ab_row17_col7, #T_8b9ab_row17_col8, #T_8b9ab_row17_col9, #T_8b9ab_row18_col7, #T_8b9ab_row18_col8, #T_8b9ab_row18_col9, #T_8b9ab_row19_col7, #T_8b9ab_row19_col8 {
#   color: black;
# }
# #T_8b9ab_row0_col9, #T_8b9ab_row1_col7, #T_8b9ab_row1_col9, #T_8b9ab_row6_col7, #T_8b9ab_row6_col9, #T_8b9ab_row7_col7, #T_8b9ab_row7_col9, #T_8b9ab_row8_col7, #T_8b9ab_row8_col9, #T_8b9ab_row12_col9, #T_8b9ab_row19_col9 {
#   color: red;
# }
# </style>
# <table id="T_8b9ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b9ab_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_8b9ab_level0_col1" class="col_heading level0 col1" >quarter</th>
#       <th id="T_8b9ab_level0_col2" class="col_heading level0 col2" >market</th>
#       <th id="T_8b9ab_level0_col3" class="col_heading level0 col3" >dur_stay</th>
#       <th id="T_8b9ab_level0_col4" class="col_heading level0 col4" >mode</th>
#       <th id="T_8b9ab_level0_col5" class="col_heading level0 col5" >purpose</th>
#       <th id="T_8b9ab_level0_col6" class="col_heading level0 col6" >area</th>
#       <th id="T_8b9ab_level0_col7" class="col_heading level0 col7" >visits</th>
#       <th id="T_8b9ab_level0_col8" class="col_heading level0 col8" >spend</th>
#       <th id="T_8b9ab_level0_col9" class="col_heading level0 col9" >nights</th>
#       <th id="T_8b9ab_level0_col10" class="col_heading level0 col10" >sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b9ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b9ab_row0_col0" class="data row0 col0" >2002</td>
#       <td id="T_8b9ab_row0_col1" class="data row0 col1" >January-March</td>
#       <td id="T_8b9ab_row0_col2" class="data row0 col2" >Belgium</td>
#       <td id="T_8b9ab_row0_col3" class="data row0 col3" >1-3  nights</td>
#       <td id="T_8b9ab_row0_col4" class="data row0 col4" >Air</td>
#       <td id="T_8b9ab_row0_col5" class="data row0 col5" >Holiday</td>
#       <td id="T_8b9ab_row0_col6" class="data row0 col6" > LONDON</td>
#       <td id="T_8b9ab_row0_col7" class="data row0 col7" >3.572186</td>
#       <td id="T_8b9ab_row0_col8" class="data row0 col8" >0.969138</td>
#       <td id="T_8b9ab_row0_col9" class="data row0 col9" >6.954456</td>
#       <td id="T_8b9ab_row0_col10" class="data row0 col10" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8b9ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b9ab_row1_col0" class="data row1 col0" >2002</td>
#       <td id="T_8b9ab_row1_col1" class="data row1 col1" >January-March</td>
#       <td id="T_8b9ab_row1_col2" class="data row1 col2" >Belgium</td>
#       <td id="T_8b9ab_row1_col3" class="data row1 col3" >1-3  nights</td>
#       <td id="T_8b9ab_row1_col4" class="data row1 col4" >Air</td>
#       <td id="T_8b9ab_row1_col5" class="data row1 col5" >Business</td>
#       <td id="T_8b9ab_row1_col6" class="data row1 col6" > LONDON</td>
#       <td id="T_8b9ab_row1_col7" class="data row1 col7" >9.284226</td>
#       <td id="T_8b9ab_row1_col8" class="data row1 col8" >2.399577</td>
#       <td id="T_8b9ab_row1_col9" class="data row1 col9" >12.604959</td>
#       <td id="T_8b9ab_row1_col10" class="data row1 col10" >19</td>
#     </tr>
#     <tr>
#       <th id="T_8b9ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8b9ab_row2_col0" class="data row2 col0" >2002</td>
#       <td id="T_8b9ab_row2_col1" class="data row2 col1" >January-March</td>
#       <td id="T_8b9ab_row2_col2" class="data row2 col2" >Belgium</td>
#       <td id="T_8b9ab_row2_col3" class="data row2 col3" >1-3  nights</td>
#       <td id="T_8b9ab_row2_col4" class="data row2 col4" >Air</td>
#       <td id="T_8b9ab_row2_col5" class="data row2 col5" >VFR</td>
#       <td id="T_8b9ab_row2_col6" class="data row2 col6" > LONDON</td>
#       <td id="T_8b9ab_row2_col7" class="data row2 col7" >0.877182</td>
#       <td id="T_8b9ab_row2_col8" class="data row2 col8" >0.089833</td>
#       <td id="T_8b9ab_row2_col9" class="data row2 col9" >2.153128</td>
#       <td id="T_8b9ab_row2_col10" class="data row2 col10" >3</td>
#     </tr>
#     <tr>
#       <th id="T_8b9ab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8b9ab_row3_col0" class="data row3 col0" >2002</td>
#       <td id="T_8b9ab_row3_col1" class="data row3 col1" >January-March</td>
#       <td id="T_8b9ab_row3_col2" class="data row3 col2" >Belgium</td>
#       <td id="T_8b9ab_row3_col3" class="data row3 col3" >1-3  nights</td>
#       <td id="T_8b9ab_row3_col4" class="data row3 col4" >Air</td>
#       <td id="T_8b9ab_row3_col5" class="data row3 col5" >Miscellaneous</td>
#       <td id="T_8b9ab_row3_col6" class="data row3 col6" > LONDON</td>
#       <td id="T_8b9ab_row3_col7" class="data row3 col7" >0.163874</td>
#       <td id="T_8b9ab_row3_col8" class="data row3 col8" >0.010160</td>
#       <td id="T_8b9ab_row3_col9" class="data row3 col9" >0.163874</td>
#       <td id="T_8b9ab_row3_col10" class="data row3 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8b9ab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8b9ab_row4_col0" class="data row4 col0" >2002</td>
#       <td id="T_8b9ab_row4_col1" class="data row4 col1" >January-March</td>
#       <td id="T_8b9ab_row4_col2" class="data row4 col2" >Belgium</td>
#       <td id="T_8b9ab_row4_col3" class="data row4 col3" >1-3  nights</td>
#       <td id="T_8b9ab_row4_col4" class="data row4 col4" >Sea</td>
#       <td id="T_8b9ab_row4_col5" class="data row4 col5" >Business</td>
#       <td id="T_8b9ab_row4_col6" class="data row4 col6" > LONDON</td>
#       <td id="T_8b9ab_row4_col7" class="data row4 col7" >1.648670</td>
#       <td id="T_8b9ab_row4_col8" class="data row4 col8" >0.016789</td>
#       <td id="T_8b9ab_row4_col9" class="data row4 col9" >1.650300</td>
#       <td id="T_8b9ab_row4_col10" class="data row4 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8b9ab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8b9ab_row5_col0" class="data row5 col0" >2002</td>
#       <td id="T_8b9ab_row5_col1" class="data row5 col1" >January-March</td>
#       <td id="T_8b9ab_row5_col2" class="data row5 col2" >Belgium</td>
#       <td id="T_8b9ab_row5_col3" class="data row5 col3" >1-3  nights</td>
#       <td id="T_8b9ab_row5_col4" class="data row5 col4" >Sea</td>
#       <td id="T_8b9ab_row5_col5" class="data row5 col5" >Miscellaneous</td>
#       <td id="T_8b9ab_row5_col6" class="data row5 col6" > LONDON</td>
#       <td id="T_8b9ab_row5_col7" class="data row5 col7" >0.590807</td>
#       <td id="T_8b9ab_row5_col8" class="data row5 col8" >0.003953</td>
#       <td id="T_8b9ab_row5_col9" class="data row5 col9" >1.772420</td>
#       <td id="T_8b9ab_row5_col10" class="data row5 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8b9ab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8b9ab_row6_col0" class="data row6 col0" >2002</td>
#       <td id="T_8b9ab_row6_col1" class="data row6 col1" >January-March</td>
#       <td id="T_8b9ab_row6_col2" class="data row6 col2" >Belgium</td>
#       <td id="T_8b9ab_row6_col3" class="data row6 col3" >1-3  nights</td>
#       <td id="T_8b9ab_row6_col4" class="data row6 col4" >Tunnel</td>
#       <td id="T_8b9ab_row6_col5" class="data row6 col5" >Ho
